# %% [markdown]
# <a href="https://colab.research.google.com/github/said3427/Tools/blob/master/cooperation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install p_tqdm
# Out:
# Collecting p_tqdm
#   Downloading p_tqdm-1.3.3.tar.gz (4.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from p_tqdm) (4.62.3)
# Collecting pathos
#   Downloading pathos-0.2.8-py2.py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 5.7 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from p_tqdm) (1.15.0)
# Collecting pox>=0.3.0
#   Downloading pox-0.3.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: multiprocess>=0.70.12 in /usr/local/lib/python3.7/dist-packages (from pathos->p_tqdm) (0.70.12.2)
# Collecting ppft>=1.6.6.4
#   Downloading ppft-1.6.6.4-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.5 MB/s
# Requirement already satisfied: dill>=0.3.4 in /usr/local/lib/python3.7/dist-packages (from pathos->p_tqdm) (0.3.4)
# Building wheels for collected packages: p-tqdm
#   Building wheel for p-tqdm (setup.py) ... done
#   Created wheel for p-tqdm: filename=p_tqdm-1.3.3-py3-none-any.whl size=3987 sha256=4b8b01f1f5df5fc26bd284bd824762255ed0d7be65cde855a2e993e4451a5c31
#   Stored in directory: /root/.cache/pip/wheels/57/6c/d6/8c4cc7d253ecfdfe0fb49f5a754d33e9c2ce1664935325b1b6
# Successfully built p-tqdm
# Installing collected packages: ppft, pox, pathos, p-tqdm
# Successfully installed p-tqdm-1.3.3 pathos-0.2.8 pox-0.3.0 ppft-1.6.6.4

# %%
import numpy as np
import scipy
from scipy.stats import norm, uniform, multivariate_normal
from scipy.optimize import minimize
import sys, ast
from random import choices, seed, random
from tqdm import tqdm
from p_tqdm import p_umap  # parallel code
from functools import partial
import os
from scipy.integrate import odeint, solve_ivp


# Create folder for output
if os.path.isdir('smc') is False:  ## if 'smc' folder does not exist:
    os.mkdir('smc')  ## create it, the output will go there

    
    
# Experimental data to fit the model to
x_data = np.array([0, 2, 4, 24])  # input data, time points
c_data = np.array(271666666.67,1200000000.00,1766666666666.67,22666666666666.70
) # input data, population/10^6
s_data = np.array([0, 550, 1970, 91700]) # input data, population/10^6

print('Time points:', x_data)
print('Cheater data:', c_data)
print('Cooperator data:', s_data, '\n')



# List parameters and upper/lower limits
parlist = [  
    {'name': 'growthc', 'lower_limit': 0.2, 'upper_limit': 0.6},  # cheater growth rate at glucose saturation
    {'name': 'growths', 'lower_limit': 0.2, 'upper_limit': 0.6},  # secretor growth rate at glucose saturation
    {'name': 'dc', 'lower_limit': 5.0, 'upper_limit': 15.0},  # cheater death rate at ampicillin saturation
    {'name': 'ds', 'lower_limit': 5.0, 'upper_limit': 15.0},  # secretor death rate at ampicillin saturation
    {'name': 'KG', 'lower_limit': 20.0, 'upper_limit': 60.0},  # glucose concentration at half max growth rate
    {'name': 'KAC', 'lower_limit': 3.0, 'upper_limit': 5.0},  # ampicillin concentration at half max death rate
    {'name': 'KAS', 'lower_limit': 1.0, 'upper_limit': 3.0},  # ampicillin concentration at half max death rate
    {'name': 'hydrolysis', 'lower_limit': 15.000, 'upper_limit': 25.000},  # rate of beta-lactamase action
    {'name': 'da', 'lower_limit': 0000.01, 'upper_limit': 0000.01},  # ampicillin degradation rate
    {'name': 'de', 'lower_limit': 0000.01, 'upper_limit': 0000.01},  # enzyme degradation rate
    {'name': 'uptake', 'lower_limit': 10.0000, 'upper_limit': 20.0000},  # rate of glucose uptake at glucose saturation
    {'name': 'secretion', 'lower_limit': 0.005, 'upper_limit': 0.008},  # rate of enzyme secretion at glucose saturation
]
    
# Create a dictionary for the parameters to make code easier to read
# Transform an array of pars e.g. p[0],p[1],p[2] into a named dictionary e.g. p['k0'],p['B'],p['n']
def pars_to_dict(pars):
    dict_pars = {} # create empty dictionary
    for parindex, par in enumerate(parlist):
        dict_pars[par['name']] = pars[parindex]
        #print(par['name'], pars[parindex], '\n')
    return dict_pars



def model(t, x, pars):
    ### This is the function you are trying to fit, so given a set of parameters (pars)
    ### and a set of concentrations x of signal/inducer, it returns the predicted response
    ### For instance for a repressive hill function:
    p = pars_to_dict(pars)

    #let x be a vector of
    cheater,secretor,glucose,ampicillin,enzyme = x 
    #set all 5 equations
    dxdt = [p['growthc'] * (glucose/(p['KG']+glucose)) * cheater - p['dc'] * ampicillin/(p['KAC']+ ampicillin), #cheaters
            p['growths'] * (glucose/(p['KG']+glucose)) * secretor - p['ds'] * ampicillin/(p['KAS']+ ampicillin), #cooperators
            - p['uptake'] * (glucose/(p['KG']+glucose)) * (cheater+secretor), #glucose
            - p['hydrolysis'] * ampicillin * enzyme-p['da'] * ampicillin, #ampicillin
            p['secretion'] * glucose/(p['KG']+glucose) * secretor - p['de'] * enzyme #enzyme
            ]
    return dxdt


def get_trajectory(timespan, initcond, t_eval, pars):
    #print('get_traj pars:', pars)
    #print('\t+ode', end='')
    traj = solve_ivp(model, t_span=timespan, y0=initcond, t_eval=t_eval, args=pars)
    #print('-ode', end='\t')
    return traj


timespan = [0, 24]
t_eval=[0,2,4,24]

def distance(par):  
    ### This function defines the distance between the data and the model for a given set of parameters
    ### for instance it can be a least squares minimization e.g. for a set of experimental observations
    ### stored as xdata and ydata:
    par = (tuple(par),)
    traj = get_trajectory(timespan, initcond, t_eval, par) 
    print(np.power(c_data - traj.y[0], 2))
    print(np.power(s_data - traj.y[1], 2))
    difference = np.sum(np.power(c_data - traj.y[0], 2) + np.power(s_data - traj.y[1], 2))
    return difference


# For each parameter take one random value from a uniform distribution between its upper/lower limits
# These will be the priors for the first iteration
def sampleprior():
    prior = []
    for parindex, par in enumerate(parlist):
        prior.append(uniform.rvs(loc=par['lower_limit'], 
                                 scale=par['upper_limit']))
    return prior

print('Initial priors:', sampleprior())

# For each parameter value proposed by the script
# Calculate how probable it is given a uniform distribution between the upper/lower limits
def evaluateprior(pars, model=None):
    ### Given a set of parameters return how probable is given the prior knowledge.
    ### If the priors are uniform distributions, this means that it will return 0 when a parameter
    ### outside the prior range is tested.
    prior = 1
    for parindex, par in enumerate(parlist):
        prior *= uniform.pdf(pars[parindex], loc=par['lower_limit'],
                             scale=par['upper_limit'])
    return prior

def GeneratePar(processcall=0, previousparlist=None, previousweights=None,
                eps_dist=100000000, kernel=None):

    # Create a function called Generate Par 
    # This function generates a valid parameter given a set of sampled pars previousparlist,previousweights
    # that is under a threshold eps_dist

    # processcall is a dummy variable that can be useful when tracking the function performance
    # it also allows the use of p_tqdm mapping that forces the use of an iterator

    seed()  # setting random seeds for each thread/process to avoid having the same random sequence in each thread
    np.random.seed()

    evaluated_distances = []
    d = eps_dist + 1  # original distance is beyond eps_dist
    while d > eps_dist:  # until a suitable parameter is found
        if previousparlist is None:  # if is the first iteration
            proposed_pars = sampleprior()
        else:
            print('+ch', end='')
            selected_pars = choices(previousparlist, weights=previousweights, k=1)  # select a point from the previous sample
            print('-ch', end='')
            proposed_pars = selected_pars + kernel.rvs()  # and perturb it

        
        if (evaluateprior(proposed_pars, model) > 0):
            print('+epd', proposed_pars[0], end=' ')
            d = distance(proposed_pars)
            if d is None:
              pass
            evaluated_distances.append(d)
            print('-epd:', d)

    # Calculate weight
    if previousparlist is None:
        weight = 1
    else:
        sum_denom = 0
        for ipars, pars in enumerate(previousparlist):
            kernel_evaluation = kernel.pdf(proposed_pars - pars)
            sum_denom += kernel_evaluation * previousweights[ipars]
        weight = evaluateprior(proposed_pars) / sum_denom
        
    print('end of GeneratePar')
    return proposed_pars, d, weight, evaluated_distances



def GeneratePars(previousparlist=None, previousweights=None, eps_dist=10000000,
                 Npars=1000, kernelfactor=1.0):
    ## Call to function GeneratePar in parallel until Npars points are accepted

    if previousparlist is not None:
        previouscovar = 2.0 * kernelfactor * np.cov(np.array(previousparlist).T)
        # print('covariance matrix previous parset:',previouscovar)
        kernel = multivariate_normal(cov=previouscovar)

    else:
        kernel = None

    trials = 0

    # for N in tqdm(range(Npars)): ## not parallel version
    #   GenerateParstePar(0,model = 'Berg',gamma = gamma, previousparlist = previousparlist,
    #   previousweights = previousweights, eps_dist = eps_dist, kernel = kernel)

    results = p_umap(
    partial(GeneratePar, previousparlist=previousparlist,
                previousweights=previousweights, eps_dist=eps_dist, kernel=kernel), range(Npars))
    accepted_distances = [result[1] for result in results]
    evaluated_distances = [res for result in results for res in result[3]]  # flatten list
    newparlist = [result[0] for result in results]
    newweights = [result[2] for result in results]

    newweights /= np.sum(newweights)  # Normalizing
    print("acceptance rate:", Npars / len(evaluated_distances))
    print("min accepted distance: ", np.min(accepted_distances))
    print("median accepted distance: ", np.median(accepted_distances))
    print("median evaluated distance: ", np.median(evaluated_distances))

    return (newparlist, newweights, accepted_distances, Npars / len(evaluated_distances))


def Sequential_ABC(initial_dist=10000, final_dist=100, Npars=1000, prior_label=None,
                   adaptative_kernel=False):
    ## Sequence of acceptance threshold start with initial_dis and keeps on reducing until
    ## a final threshold final_dist is reached.

    ## prior_label can be used to restart a sampling from a previous prior distribution in case
    ## further exploration with a lower epsilon is needed

    distance = initial_dist
    not_converged = True
    last_round = False
    kernelfactor = 1.0

    if prior_label is None:
        pars = None
        weights = None
        idistance = 0
    else:  # a file with the label is used to load the posterior, use always numerical (not 'final')
        pars = np.loadtxt('smc/pars_{}_{}_{}_{}.out'.format(model, sto, gamma, prior_label))
        weights = np.loadtxt('smc/weights_{}_{}_{}_{}.out'.format(model, sto, gamma, prior_label))
        accepted_distances = np.loadtxt('smc/distances_{}_{}_{}_{}.out'.format(model, sto, gamma, prior_label))
        distance = np.median(accepted_distances)
        idistance = prior_label

    while not_converged:

        idistance += 1
        print("SMC step with target distance: {}".format(distance))
        pars, weights, accepted_distances, acceptance = GeneratePars(previousparlist=pars,
                                                                     previousweights=weights, eps_dist=distance,
                                                                     Npars=Npars, kernelfactor=kernelfactor)
        proposed_dist = np.median(accepted_distances)
        if last_round is True:
            not_converged = False
            label = 'final'
        else:
            label = idistance
        if proposed_dist < final_dist:
            distance = final_dist
            last_round = True
        else:
            distance = proposed_dist
        np.savetxt('smc/pars_{}.out'.format(label), pars)
        np.savetxt('smc/weights_{}.out'.format(label), weights)
        np.savetxt('smc/distances_{}.out'.format(label), accepted_distances)

        if acceptance < 0.1 and kernelfactor > 0.1 and adaptative_kernel:
            kernelfactor = kernelfactor * 0.7
            print('Reducing kernel width to : ', kernelfactor)
        elif acceptance > 0.5 and kernelfactor < 1 and adaptative_kernel:
            kernelfactor = kernelfactor / 0.7
            print('Increasing kernel width to : ', kernelfactor)

    print('ABC converged succesfully!\n')
# Out:
#   File "<ipython-input-54-953ca02b2857>", line 93
#     if traj.status
#                   ^
# SyntaxError: invalid syntax

# %%
def distance(par):  
    ### This function defines the distance between the data and the model for a given set of parameters
    ### for instance it can be a least squares minimization e.g. for a set of experimental observations
    ### stored as xdata and ydata:
    par = (tuple(par),)
    traj = get_trajectory(timespan, initcond, t_eval, par)
    print(traj)
    print(c_data, traj.y[0])
    print(s_data, traj.y[1])
    difference = np.sum(np.power(c_data - traj.y[0], 2) + np.power(s_data - traj.y[1], 2))
    return difference

# %%
processcall=0
previousparlist=None
previousweights=None
eps_dist=1000000000000
kernel=None

#seed()  # setting random seeds for each thread/process to avoid having the same random sequence in each thread
#np.random.seed()

evaluated_distances = []
d = eps_dist + 1  # original distance is beyond eps_dist
while d > eps_dist:  # until a suitable parameter is found
     if previousparlist is None:  # if is the first iteration
         proposed_pars = sampleprior()
     else:
         print('+ch', end='')
         selected_pars = choices(previousparlist, weights=previousweights, k=1)  # select a point from the previous sample
         print('-ch', end='')
         proposed_pars = selected_pars + kernel.rvs()  # and perturb it
     
     if (evaluateprior(proposed_pars, model) > 0):
         print('+epd', proposed_pars[0], end=' ')
         d = distance(proposed_pars)
         if d is None:
           break
         evaluated_distances.append(d)
         print('distance:', d)

# Calculate weight
if previousparlist is None:
    weight = 1
else:
    sum_denom = 0
    for ipars, pars in enumerate(previousparlist):
        kernel_evaluation = kernel.pdf(proposed_pars - pars)
        sum_denom += kernel_evaluation * previousweights[ipars]
    weight = evaluateprior(proposed_pars) / sum_denom
    
print('end of GeneratePar')
# Out:
# Streaming output truncated to the last 5000 lines.
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+02,  3.46724391e+02,  3.46724391e+02,
#          3.46724391e+02],
#        [ 4.16666660e+01,  5.04624025e+01,  5.04624025e+01,
#          5.04624025e+01],
#        [ 2.00000000e+03, -1.35346208e-06, -2.19083410e-07,
#          2.58944145e-07],
#        [ 1.00000000e+02,  2.07559854e-36,  1.29816784e-73,
#          0.00000000e+00],
#        [ 1.00000000e+00,  1.12840165e+00,  1.10017168e+00,
#          8.53941134e-01]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   346.72439061 346.72439056 346.72439054]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   50.46240253 50.46240253 50.46240253]
# distance: 3.3201611383719224e+16
# +epd 0.7266215815312616   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 5462
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.72381655e+002,  3.72381655e+002,
#          3.72381655e+002],
#        [ 4.16666660e+001,  4.62497142e+001,  4.62497142e+001,
#          4.62497142e+001],
#        [ 2.00000000e+003, -1.16401378e-006, -1.26219124e-006,
#          1.45257675e-007],
#        [ 1.00000000e+002,  5.98834466e-030,  6.67140259e-061,
#          4.94065646e-324],
#        [ 1.00000000e+000,  1.17771960e+000,  1.14301867e+000,
#          8.47554304e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   372.38165502 372.38165502 372.38165495]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   46.24971417 46.24971417 46.24971417]
# distance: 3.320160121190351e+16
# +epd 0.7790871271977233   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 12344
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.69074962e+002,  3.69074962e+002,
#          3.69074962e+002],
#        [ 4.16666660e+001,  4.85462928e+001,  4.85462928e+001,
#          4.85462928e+001],
#        [ 2.00000000e+003, -2.38141773e-007, -5.20836376e-007,
#          3.52422418e-007],
#        [ 1.00000000e+002,  2.64186714e-035,  3.51069831e-071,
#          4.94065646e-324],
#        [ 1.00000000e+000,  1.11422392e+000,  1.07696057e+000,
#          7.66431030e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   369.07496196 369.07496197 369.07496193]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   48.5462928  48.5462928  48.54629279]
# distance: 3.3201602437142136e+16
# +epd 0.21032321265517703   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 9950
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  2.86485184e+002,  2.86485184e+002,
#          2.86485184e+002],
#        [ 4.16666660e+001,  4.86417336e+001,  4.86417336e+001,
#          4.86417336e+001],
#        [ 2.00000000e+003, -1.19382860e-006, -4.63431624e-007,
#          1.04301320e-006],
#        [ 1.00000000e+002,  6.95678175e-027,  2.08550477e-054,
#          2.55682457e-290],
#        [ 1.00000000e+000,  1.05343114e+000,  1.02366460e+000,
#          7.68551602e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   286.48518449 286.48518449 286.48518448]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   48.64173364 48.64173363 48.64173363]
# distance: 3.320163583787367e+16
# +epd 0.42356660535629487   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 8036
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 2.97944593e+002, 2.97944593e+002,
#         2.97944593e+002],
#        [4.16666660e+001, 4.49119655e+001, 4.49119655e+001,
#         4.49119655e+001],
#        [2.00000000e+003, 3.49378926e-007, 1.29553879e-006,
#         7.96244083e-007],
#        [1.00000000e+002, 2.44132468e-025, 4.30034586e-051,
#         1.97643776e-262],
#        [1.00000000e+000, 1.03210965e+000, 9.94618154e-001,
#         6.87008023e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   297.94459346 297.94459345 297.94459346]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   44.91196551 44.91196551 44.91196551]
# distance: 3.320163138511054e+16
# +epd 0.4092599296815532   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 8102
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 3.01950848e+002, 3.01950848e+002,
#         3.01950848e+002],
#        [4.16666660e+001, 4.59050195e+001, 4.59050195e+001,
#         4.59050195e+001],
#        [2.00000000e+003, 5.24326904e-007, 1.95219556e-006,
#         7.32708830e-007],
#        [1.00000000e+002, 1.91129113e-020, 1.12007586e-041,
#         1.62459371e-222],
#        [1.00000000e+000, 1.07194566e+000, 1.04040349e+000,
#         7.71777509e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   301.95084806 301.95084804 301.95084806]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   45.90501947 45.90501947 45.90501947]
# distance: 3.3201629716155764e+16
# +epd 0.6065599542547205   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 8102
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 3.26173424e+002, 3.26173424e+002,
#         3.26173424e+002],
#        [4.16666660e+001, 4.89506016e+001, 4.89506016e+001,
#         4.89506016e+001],
#        [2.00000000e+003, 3.55504067e-007, 9.34243116e-007,
#         8.16667999e-007],
#        [1.00000000e+002, 6.67393722e-022, 1.56860506e-044,
#         9.01892369e-231],
#        [1.00000000e+000, 1.12795442e+000, 1.08760128e+000,
#         7.55529321e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   326.17342407 326.17342405 326.17342406]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   48.95060158 48.95060158 48.95060158]
# distance: 3.3201619769924136e+16
# +epd 0.5170561186755499   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 5318
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 3.15871048e+002, 3.15871048e+002,
#         3.15871048e+002],
#        [4.16666660e+001, 4.64286750e+001, 4.64286750e+001,
#         4.64286750e+001],
#        [2.00000000e+003, 1.71339995e-006, 1.25496190e-007,
#         7.31233321e-007],
#        [1.00000000e+002, 9.54902725e-029, 2.12891266e-058,
#         1.53160350e-322],
#        [1.00000000e+000, 1.09890406e+000, 1.07544243e+000,
#         8.66684548e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   315.87104829 315.87104833 315.87104832]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   46.42867497 46.42867497 46.42867497]
# distance: 3.320162406020841e+16
# +epd 0.5309749362537928   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 11612
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.03367864e+002,  3.03367864e+002,
#          3.03367864e+002],
#        [ 4.16666660e+001,  4.48007403e+001,  4.48007403e+001,
#          4.48007403e+001],
#        [ 2.00000000e+003, -4.21553238e-007,  7.61789867e-008,
#          1.59227656e-007],
#        [ 1.00000000e+002,  1.58137897e-020,  7.50734383e-042,
#          5.66281373e-226],
#        [ 1.00000000e+000,  1.06623629e+000,  1.03755181e+000,
#          7.89901857e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   303.36786404 303.36786403 303.36786403]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   44.80074032 44.80074032 44.80074032]
# distance: 3.320162919697461e+16
# +epd 0.602871390241776   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 7766
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 3.30367131e+002, 3.30367131e+002,
#         3.30367131e+002],
#        [4.16666660e+001, 4.78725880e+001, 4.78725880e+001,
#         4.78725880e+001],
#        [2.00000000e+003, 4.61161577e-008, 8.55250947e-007,
#         6.16477294e-007],
#        [1.00000000e+002, 1.77572688e-027, 8.92859760e-056,
#         9.40366128e-305],
#        [1.00000000e+000, 1.06675124e+000, 1.04173855e+000,
#         8.21702307e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   330.3671315  330.36713147 330.36713148]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   47.87258799 47.87258799 47.87258799]
# distance: 3.3201618126360864e+16
# +epd 0.7358419584068441   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 5042
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 3.46229945e+002, 3.46229945e+002,
#         3.46229945e+002],
#        [4.16666660e+001, 4.64856841e+001, 4.64856841e+001,
#         4.64856841e+001],
#        [2.00000000e+003, 9.49108532e-007, 3.11264084e-007,
#         1.32414273e-006],
#        [1.00000000e+002, 2.71062591e-029, 6.45332710e-059,
#         3.31462557e-301],
#        [1.00000000e+000, 1.03634040e+000, 9.97757514e-001,
#         6.82732834e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   346.2299448  346.22994482 346.22994479]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   46.48568407 46.48568407 46.48568407]
# distance: 3.3201611778046844e+16
# +epd 0.2665465114574678   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 10394
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+02, 2.87609148e+02, 2.87609148e+02, 2.87609148e+02],
#        [4.16666660e+01, 4.78838380e+01, 4.78838380e+01, 4.78838380e+01],
#        [2.00000000e+03, 3.91392268e-07, 6.96843842e-07, 5.20575031e-07],
#        [1.00000000e+02, 4.96926549e-37, 8.58953149e-75, 0.00000000e+00],
#        [1.00000000e+00, 1.10544505e+00, 1.08206397e+00, 8.73797321e-01]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   287.60914764 287.60914764 287.60914764]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   47.88383797 47.88383797 47.88383797]
# distance: 3.320163542029726e+16
# +epd 0.5417384223750534   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 5762
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 3.07485874e+002, 3.07485874e+002,
#         3.07485874e+002],
#        [4.16666660e+001, 4.36180824e+001, 4.36180824e+001,
#         4.36180824e+001],
#        [2.00000000e+003, 7.60121920e-007, 9.96135079e-007,
#         6.52333781e-007],
#        [1.00000000e+002, 1.00048540e-033, 1.27340978e-067,
#         4.94065646e-324],
#        [1.00000000e+000, 1.04354948e+000, 1.00568974e+000,
#         6.94982338e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   307.48587399 307.48587398 307.48587399]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666  43.6180824 43.6180824 43.6180824]
# distance: 3.320162758914226e+16
# +epd 0.769481204889314   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 4058
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 3.93663831e+002, 3.93663831e+002,
#         3.93663831e+002],
#        [4.16666660e+001, 4.71250777e+001, 4.71250777e+001,
#         4.71250777e+001],
#        [2.00000000e+003, 1.12596556e-006, 1.91585899e-006,
#         4.48979485e-007],
#        [1.00000000e+002, 3.69237206e-017, 1.52014373e-035,
#         8.28280154e-198],
#        [1.00000000e+000, 1.14987915e+000, 1.12353352e+000,
#         8.91095783e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   393.66383064 393.66383059 393.66383068]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   47.12507768 47.12507768 47.12507768]
# distance: 3.3201592561051544e+16
# +epd 0.2508658871710699   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 9716
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+02, 2.92014487e+02, 2.92014487e+02, 2.92014487e+02],
#        [4.16666660e+01, 4.58640281e+01, 4.58640281e+01, 4.58640281e+01],
#        [2.00000000e+03, 1.35476956e-06, 9.55243550e-07, 9.43507639e-07],
#        [1.00000000e+02, 2.63216944e-33, 2.99814065e-67, 0.00000000e+00],
#        [1.00000000e+00, 1.04279360e+00, 1.01814162e+00, 8.01505514e-01]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   292.01448706 292.01448706 292.01448706]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   45.86402807 45.86402808 45.86402808]
# distance: 3.320163373715783e+16
# +epd 0.32801926915608304   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 9236
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  2.95061670e+002,  2.95061670e+002,
#          2.95061670e+002],
#        [ 4.16666660e+001,  4.71469673e+001,  4.71469673e+001,
#          4.71469673e+001],
#        [ 2.00000000e+003,  1.42471287e-006, -1.40248128e-006,
#          1.11697941e-006],
#        [ 1.00000000e+002,  4.10282315e-018,  5.19439104e-037,
#          1.63283142e-197],
#        [ 1.00000000e+000,  1.03479873e+000,  1.00381329e+000,
#          7.40667832e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   295.06167001 295.06167005 295.06167001]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   47.14696728 47.14696729 47.14696728]
# distance: 3.320163244195606e+16
# +epd 0.749077303667752   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 12860
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+02,  3.80097479e+02,  3.80097479e+02,
#          3.80097479e+02],
#        [ 4.16666660e+01,  4.90059375e+01,  4.90059375e+01,
#          4.90059375e+01],
#        [ 2.00000000e+03, -6.80992709e-07,  4.87521027e-07,
#          1.69256415e-07],
#        [ 1.00000000e+02,  9.10897683e-37,  4.24498013e-75,
#          0.00000000e+00],
#        [ 1.00000000e+00,  1.22117437e+00,  1.19681114e+00,
#          9.78374351e-01]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   380.09747861 380.09747854 380.09747856]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   49.00593747 49.00593746 49.00593746]
# distance: 3.3201597956364508e+16
# +epd 0.7341040512920467   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 6290
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.24115919e+002,  3.24115919e+002,
#          3.24115919e+002],
#        [ 4.16666660e+001,  4.80234805e+001,  4.80234805e+001,
#          4.80234805e+001],
#        [ 2.00000000e+003,  1.12136428e-006, -7.08813649e-008,
#          2.40758842e-007],
#        [ 1.00000000e+002,  1.10647456e-029,  4.34558233e-060,
#          4.94065646e-324],
#        [ 1.00000000e+000,  1.04705591e+000,  1.02358171e+000,
#          8.15922587e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   324.11591858 324.11591861 324.1159186 ]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   48.02348047 48.02348047 48.02348047]
# distance: 3.3201620647438356e+16
# +epd 0.7047816753702087   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 6926
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.82826748e+002,  3.82826748e+002,
#          3.82826748e+002],
#        [ 4.16666660e+001,  5.53993487e+001,  5.53993487e+001,
#          5.53993487e+001],
#        [ 2.00000000e+003,  2.54498646e-007, -6.25843659e-007,
#          6.31973295e-007],
#        [ 1.00000000e+002,  3.95986773e-025,  1.87969202e-051,
#          2.12722520e-276],
#        [ 1.00000000e+000,  1.19829621e+000,  1.16374515e+000,
#          8.68550113e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   382.82674792 382.82674797 382.8267479 ]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   55.39934871 55.39934872 55.39934871]
# distance: 3.3201596540009588e+16
# +epd 0.29254128549301905   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 5450
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.02031277e+002,  3.02031277e+002,
#          3.02031277e+002],
#        [ 4.16666660e+001,  5.14628521e+001,  5.14628521e+001,
#          5.14628521e+001],
#        [ 2.00000000e+003, -4.35837250e-007, -1.10191613e-006,
#          7.22025633e-007],
#        [ 1.00000000e+002,  4.72844339e-018,  4.16430573e-037,
#          8.38024278e-202],
#        [ 1.00000000e+000,  1.11033677e+000,  1.08065143e+000,
#          8.24128145e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   302.0312766  302.03127661 302.03127658]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   51.46285206 51.46285206 51.46285205]
# distance: 3.3201629412020056e+16
# +epd 0.41099990313743184   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 4010
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+02,  3.38575643e+02,  3.38575643e+02,
#          3.38575643e+02],
#        [ 4.16666660e+01,  4.68652697e+01,  4.68652697e+01,
#          4.68652697e+01],
#        [ 2.00000000e+03,  1.81783463e-07, -3.33535444e-07,
#          1.50233520e-06],
#        [ 1.00000000e+02,  3.63505628e-32,  3.33118378e-67,
#          0.00000000e+00],
#        [ 1.00000000e+00,  1.24371976e+00,  1.20074596e+00,
#          8.44767344e-01]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   338.57564342 338.57564344 338.57564338]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   46.86526975 46.86526975 46.86526974]
# distance: 3.3201614855460156e+16
# +epd 0.6261648401883515   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 15926
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.20591172e+002,  3.20591172e+002,
#          3.20591172e+002],
#        [ 4.16666660e+001,  4.34678293e+001,  4.34678293e+001,
#          4.34678293e+001],
#        [ 2.00000000e+003, -7.43099177e-007,  3.04382940e-007,
#          1.38094941e-007],
#        [ 1.00000000e+002,  3.02098407e-025,  5.73025608e-051,
#          1.89975304e-261],
#        [ 1.00000000e+000,  1.06277801e+000,  1.02362202e+000,
#          7.03250779e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   320.59117178 320.59117175 320.59117176]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666  43.4678293 43.4678293 43.4678293]
# distance: 3.320162229573515e+16
# +epd 0.6608392098307485   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 5162
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.67495690e+002,  3.67495690e+002,
#          3.67495690e+002],
#        [ 4.16666660e+001,  5.44815806e+001,  5.44815806e+001,
#          5.44815806e+001],
#        [ 2.00000000e+003, -3.88864333e-007,  1.36577975e-006,
#          4.29098512e-007],
#        [ 1.00000000e+002,  8.75996537e-016,  1.05836042e-032,
#          5.70939867e-178],
#        [ 1.00000000e+000,  1.14594206e+000,  1.11391846e+000,
#          8.38997803e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   367.49568998 367.49568989 367.49568994]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   54.48158062 54.48158061 54.48158062]
# distance: 3.3201602785865652e+16
# +epd 0.3739105468048648   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 8780
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+02,  3.01179682e+02,  3.01179682e+02,
#          3.01179682e+02],
#        [ 4.16666660e+01,  4.95352863e+01,  4.95352863e+01,
#          4.95352863e+01],
#        [ 2.00000000e+03,  1.36510370e-08, -7.54843198e-07,
#          4.46173119e-07],
#        [ 1.00000000e+02,  7.19978580e-37,  1.72777225e-74,
#          0.00000000e+00],
#        [ 1.00000000e+00,  1.12076032e+00,  1.09416370e+00,
#          8.60553494e-01]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   301.17968183 301.17968184 301.17968182]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   49.53528632 49.53528633 49.53528632]
# distance: 3.3201629850665656e+16
# +epd 0.22856070795295805   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 10292
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  2.97775524e+002,  2.97775524e+002,
#          2.97775524e+002],
#        [ 4.16666660e+001,  4.85413294e+001,  4.85413294e+001,
#          4.85413294e+001],
#        [ 2.00000000e+003, -3.20537801e-007, -2.03570878e-007,
#          2.77666741e-007],
#        [ 1.00000000e+002,  8.31493602e-017,  9.78426526e-035,
#          7.41521594e-194],
#        [ 1.00000000e+000,  1.10130506e+000,  1.07724975e+000,
#          8.63781869e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   297.7755244  297.7755244  297.77552439]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   48.54132938 48.54132938 48.54132938]
# distance: 3.3201631276131956e+16
# +epd 0.2532894131382386   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 19136
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  2.89322677e+002,  2.89322677e+002,
#          2.89322677e+002],
#        [ 4.16666660e+001,  4.13921465e+001,  4.13921465e+001,
#          4.13921465e+001],
#        [ 2.00000000e+003, -6.34232584e-007, -1.02437446e-007,
#          2.20742172e-007],
#        [ 1.00000000e+002,  3.08760823e-015,  2.57423125e-031,
#          5.34214552e-167],
#        [ 1.00000000e+000,  1.04577429e+000,  1.01320040e+000,
#          7.38361923e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   289.32267697 289.32267697 289.32267697]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   41.39214651 41.39214651 41.39214651]
# distance: 3.320163504446042e+16
# +epd 0.6198150365509858   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 10862
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.38029031e+002,  3.38029032e+002,
#          3.38029031e+002],
#        [ 4.16666660e+001,  4.38831686e+001,  4.38831686e+001,
#          4.38831686e+001],
#        [ 2.00000000e+003,  2.05492583e-006, -1.17940579e-006,
#          5.79749989e-007],
#        [ 1.00000000e+002,  1.25973689e-024,  2.69372139e-050,
#          4.76236754e-277],
#        [ 1.00000000e+000,  1.14209232e+000,  1.11616250e+000,
#          8.87134716e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   338.02903142 338.02903153 338.02903147]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   43.88316864 43.88316865 43.88316864]
# distance: 3.320161522228195e+16
# +epd 0.6879449001487301   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 5960
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+02, 3.49187488e+02, 3.49187488e+02, 3.49187488e+02],
#        [4.16666660e+01, 5.13437942e+01, 5.13437942e+01, 5.13437942e+01],
#        [2.00000000e+03, 1.06377610e-07, 1.43373086e-06, 6.43546461e-07],
#        [1.00000000e+02, 1.24738751e-35, 1.01051039e-71, 0.00000000e+00],
#        [1.00000000e+00, 1.09546441e+00, 1.05817830e+00, 7.48453194e-01]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   349.18748819 349.18748814 349.18748817]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   51.34379421 51.34379421 51.34379421]
# distance: 3.3201610344388704e+16
# +epd 0.6336724582819138   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 5648
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.18218532e+002,  3.18218532e+002,
#          3.18218532e+002],
#        [ 4.16666660e+001,  4.32101929e+001,  4.32101929e+001,
#          4.32101929e+001],
#        [ 2.00000000e+003,  6.72718133e-007, -4.78224137e-008,
#          8.68701290e-007],
#        [ 1.00000000e+002,  3.85433863e-023,  3.87182178e-047,
#          3.77835221e-256],
#        [ 1.00000000e+000,  1.10417839e+000,  1.07619265e+000,
#          8.32526005e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   318.21853234 318.21853236 318.21853234]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   43.21019289 43.21019289 43.21019289]
# distance: 3.320162326799599e+16
# +epd 0.47767919385975316   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 10598
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 3.01380549e+002, 3.01380549e+002,
#         3.01380549e+002],
#        [4.16666660e+001, 4.78411715e+001, 4.78411715e+001,
#         4.78411715e+001],
#        [2.00000000e+003, 4.06554129e-007, 3.50320403e-007,
#         6.78722015e-007],
#        [1.00000000e+002, 4.18477928e-023, 1.16952665e-046,
#         3.59686874e-239],
#        [1.00000000e+000, 1.01539956e+000, 9.77759951e-001,
#         6.70169990e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   301.38054889 301.38054889 301.38054888]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   47.84117154 47.84117154 47.84117154]
# distance: 3.320162985220949e+16
# +epd 0.4806508029165917   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 7880
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 3.23170928e+002, 3.23170928e+002,
#         3.23170928e+002],
#        [4.16666660e+001, 5.12419956e+001, 5.12419956e+001,
#         5.12419956e+001],
#        [2.00000000e+003, 5.27802939e-008, 9.43320716e-007,
#         1.83430895e-007],
#        [1.00000000e+002, 4.81342545e-038, 6.13023288e-077,
#         4.94065646e-324],
#        [1.00000000e+000, 1.17240657e+000, 1.13910833e+000,
#         8.53950857e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   323.17092829 323.17092827 323.17092829]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   51.24199563 51.24199562 51.24199563]
# distance: 3.3201620872377268e+16
# +epd 0.34401020841281804   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 10742
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  2.91163798e+002,  2.91163798e+002,
#          2.91163798e+002],
#        [ 4.16666660e+001,  4.71974108e+001,  4.71974108e+001,
#          4.71974107e+001],
#        [ 2.00000000e+003, -5.25782576e-007,  1.67902043e-007,
#          1.14641525e-006],
#        [ 1.00000000e+002,  3.70320568e-026,  4.60705390e-053,
#          3.82321617e-289],
#        [ 1.00000000e+000,  1.06214422e+000,  1.03672702e+000,
#          8.13717573e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   291.16379843 291.16379842 291.16379841]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   47.19741075 47.19741075 47.19741075]
# distance: 3.320163401607843e+16
# +epd 0.46933280350334317   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 5432
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.06141919e+002,  3.06141919e+002,
#          3.06141919e+002],
#        [ 4.16666660e+001,  4.80513745e+001,  4.80513745e+001,
#          4.80513745e+001],
#        [ 2.00000000e+003, -7.53829796e-007,  3.93786853e-007,
#          6.39066296e-007],
#        [ 1.00000000e+002,  4.25758307e-015,  3.84907346e-031,
#          1.96438355e-171],
#        [ 1.00000000e+000,  1.03913288e+000,  1.01359179e+000,
#          7.90283806e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   306.14191888 306.14191886 306.14191886]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   48.05137452 48.05137451 48.05137451]
# distance: 3.320162791608735e+16
# +epd 0.3691507052478107   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 6548
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 2.92591368e+002, 2.92591368e+002,
#         2.92591368e+002],
#        [4.16666660e+001, 4.50631592e+001, 4.50631592e+001,
#         4.50631592e+001],
#        [2.00000000e+003, 8.39150102e-007, 8.03230699e-007,
#         3.21991335e-007],
#        [1.00000000e+002, 3.64771797e-018, 5.76706168e-037,
#         3.42451034e-190],
#        [1.00000000e+000, 1.04636002e+000, 1.00701931e+000,
#         6.86442887e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   292.59136834 292.59136834 292.59136835]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   45.06315921 45.06315921 45.06315921]
# distance: 3.3201633542961876e+16
# +epd 0.29395352154277804   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 5474
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  2.96986224e+002,  2.96986224e+002,
#          2.96986224e+002],
#        [ 4.16666660e+001,  4.82859645e+001,  4.82859645e+001,
#          4.82859645e+001],
#        [ 2.00000000e+003,  4.33833387e-007, -1.51021416e-006,
#          5.04564453e-007],
#        [ 1.00000000e+002,  1.72907686e-029,  1.07265685e-059,
#          4.94065646e-324],
#        [ 1.00000000e+000,  1.05659348e+000,  1.03077329e+000,
#          8.04850923e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   296.98622431 296.98622433 296.98622431]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   48.28596445 48.28596446 48.28596445]
# distance: 3.320163160786263e+16
# +epd 0.519183878926484   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 5282
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.36126547e+002,  3.36126547e+002,
#          3.36126547e+002],
#        [ 4.16666660e+001,  5.22102324e+001,  5.22102324e+001,
#          5.22102324e+001],
#        [ 2.00000000e+003,  5.97032827e-007, -4.11044629e-007,
#          6.43056407e-007],
#        [ 1.00000000e+002,  4.26447463e-031,  7.83004938e-063,
#          4.94065646e-324],
#        [ 1.00000000e+000,  1.12951485e+000,  1.08842421e+000,
#          7.51381835e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   336.12654729 336.12654732 336.12654729]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   52.21023241 52.21023242 52.21023241]
# distance: 3.3201615584853308e+16
# +epd 0.30558095939809393   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 16706
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 2.92784805e+002, 2.92784805e+002,
#         2.92784805e+002],
#        [4.16666660e+001, 4.53909351e+001, 4.53909351e+001,
#         4.53909351e+001],
#        [2.00000000e+003, 7.93299747e-007, 8.12649903e-007,
#         7.90726187e-007],
#        [1.00000000e+002, 3.25924813e-033, 5.60196474e-067,
#         4.94065646e-324],
#        [1.00000000e+000, 1.03834670e+000, 1.01218000e+000,
#         7.84172187e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   292.78480528 292.78480528 292.78480528]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   45.39093513 45.39093513 45.39093513]
# distance: 3.3201633448703668e+16
# +epd 0.4154017512730678   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 12188
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.16449334e+002,  3.16449334e+002,
#          3.16449334e+002],
#        [ 4.16666660e+001,  5.45979028e+001,  5.45979028e+001,
#          5.45979028e+001],
#        [ 2.00000000e+003, -2.28652552e-007,  1.39505030e-006,
#          6.65272063e-007],
#        [ 1.00000000e+002,  2.85623470e-034,  1.18516110e-069,
#          4.94065646e-324],
#        [ 1.00000000e+000,  1.15962468e+000,  1.13536476e+000,
#          9.18998911e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   316.44933418 316.44933414 316.44933416]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   54.59790283 54.59790282 54.59790283]
# distance: 3.320162342708688e+16
# +epd 0.2848660745386743   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 7688
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  2.88356615e+002,  2.88356615e+002,
#          2.88356615e+002],
#        [ 4.16666660e+001,  4.74639530e+001,  4.74639530e+001,
#          4.74639530e+001],
#        [ 2.00000000e+003, -3.68361275e-007, -1.55115058e-006,
#          9.42219144e-007],
#        [ 1.00000000e+002,  2.87270309e-014,  2.44717054e-029,
#          3.21075988e-153],
#        [ 1.00000000e+000,  1.05529874e+000,  1.01731720e+000,
#          7.05124915e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   288.35661511 288.35661512 288.3566151 ]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   47.46395303 47.46395303 47.46395302]
# distance: 3.320163513848539e+16
# +epd 0.24121455476148232   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 7076
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 3.02850257e+002, 3.02850257e+002,
#         3.02850257e+002],
#        [4.16666660e+001, 4.89471491e+001, 4.89471491e+001,
#         4.89471491e+001],
#        [2.00000000e+003, 1.67333567e-006, 1.03408582e-006,
#         8.96353432e-007],
#        [1.00000000e+002, 1.56268175e-019, 6.17357796e-040,
#         3.31430564e-206],
#        [1.00000000e+000, 1.11993999e+000, 1.07781412e+000,
#         7.34573116e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   302.85025745 302.85025746 302.85025747]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   48.94714909 48.94714909 48.94714909]
# distance: 3.320162920370298e+16
# +epd 0.26903953485563264   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 18872
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  2.88177837e+002,  2.88177837e+002,
#          2.88177837e+002],
#        [ 4.16666660e+001,  4.24628171e+001,  4.24628171e+001,
#          4.24628171e+001],
#        [ 2.00000000e+003, -6.57694177e-007,  1.21949376e-006,
#          5.09933391e-007],
#        [ 1.00000000e+002,  7.71556547e-017,  1.58726624e-034,
#          3.59305765e-187],
#        [ 1.00000000e+000,  1.02612208e+000,  9.98433773e-001,
#          7.59489157e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   288.17783687 288.17783686 288.17783686]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666  42.4628171 42.4628171 42.4628171]
# distance: 3.320163545519603e+16
# +epd 0.5366321216070102   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 6926
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+02,  3.12544517e+02,  3.12544517e+02,
#          3.12544517e+02],
#        [ 4.16666660e+01,  4.49196259e+01,  4.49196259e+01,
#          4.49196258e+01],
#        [ 2.00000000e+03, -1.15252961e-06, -7.48885100e-07,
#          5.12943283e-07],
#        [ 1.00000000e+02,  2.55182149e-33,  7.69251211e-67,
#          0.00000000e+00],
#        [ 1.00000000e+00,  1.07309097e+00,  1.03176324e+00,
#          6.96650821e-01]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   312.54451669 312.54451668 312.54451665]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   44.91962585 44.91962585 44.91962585]
# distance: 3.3201625479448772e+16
# +epd 0.37254389198924615   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 8228
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 2.97018582e+002, 2.97018582e+002,
#         2.97018582e+002],
#        [4.16666660e+001, 4.28768311e+001, 4.28768311e+001,
#         4.28768311e+001],
#        [2.00000000e+003, 4.63670931e-007, 2.00207151e-006,
#         8.97755096e-007],
#        [1.00000000e+002, 6.83896635e-021, 1.59142549e-042,
#         1.30731702e-224],
#        [1.00000000e+000, 1.09556092e+000, 1.06091531e+000,
#         7.69347505e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   297.01858241 297.01858239 297.0185824 ]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   42.87683107 42.87683107 42.87683107]
# distance: 3.3201631859112444e+16
# +epd 0.38067849326716674   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 14750
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  2.99582323e+002,  2.99582323e+002,
#          2.99582323e+002],
#        [ 4.16666660e+001,  4.72507201e+001,  4.72507201e+001,
#          4.72507201e+001],
#        [ 2.00000000e+003, -2.85094461e-007, -2.12584690e-007,
#          1.20305272e-006],
#        [ 1.00000000e+002,  1.96694493e-024,  1.34283386e-049,
#          1.09559257e-267],
#        [ 1.00000000e+000,  1.04668322e+000,  1.01923106e+000,
#          7.81351619e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   299.58232309 299.58232309 299.58232307]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   47.25072013 47.25072013 47.25072013]
# distance: 3.3201630608399532e+16
# +epd 0.6605389990258916   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 7328
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.12100684e+002,  3.12100684e+002,
#          3.12100684e+002],
#        [ 4.16666660e+001,  4.28135899e+001,  4.28135899e+001,
#          4.28135899e+001],
#        [ 2.00000000e+003, -3.28882605e-007,  3.52479568e-007,
#          3.80479063e-007],
#        [ 1.00000000e+002,  1.51130116e-024,  1.48704240e-049,
#          4.56703687e-255],
#        [ 1.00000000e+000,  1.04522301e+000,  1.00753695e+000,
#          6.97880672e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   312.10068424 312.10068423 312.10068423]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   42.81358989 42.81358989 42.81358989]
# distance: 3.320162576188683e+16
# +epd 0.5926960862301696   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 7718
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 3.08212200e+002, 3.08212200e+002,
#         3.08212200e+002],
#        [4.16666660e+001, 4.21963961e+001, 4.21963961e+001,
#         4.21963961e+001],
#        [2.00000000e+003, 8.45734775e-007, 8.11241114e-007,
#         3.64913052e-007],
#        [1.00000000e+002, 8.99155607e-017, 2.86392297e-034,
#         8.22839923e-179],
#        [1.00000000e+000, 1.04706949e+000, 1.01032478e+000,
#         7.06831613e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   308.21220049 308.21220049 308.2122005 ]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666  42.1963961 42.1963961 42.1963961]
# distance: 3.32016273648383e+16
# +epd 0.6093699703909359   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 11930
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.37573355e+002,  3.37573355e+002,
#          3.37573355e+002],
#        [ 4.16666660e+001,  4.58569445e+001,  4.58569445e+001,
#          4.58569445e+001],
#        [ 2.00000000e+003, -1.36338000e-007,  1.65257891e-006,
#          6.05984218e-007],
#        [ 1.00000000e+002,  9.75673207e-027,  4.70255678e-054,
#          1.75883575e-279],
#        [ 1.00000000e+000,  1.08396201e+000,  1.04572046e+000,
#          7.30181867e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   337.5733547  337.57335464 337.57335468]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   45.85694446 45.85694446 45.85694446]
# distance: 3.3201615310135172e+16
# +epd 0.6548008067373559   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 6176
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.15114037e+002,  3.15114037e+002,
#          3.15114037e+002],
#        [ 4.16666660e+001,  4.41202615e+001,  4.41202615e+001,
#          4.41202615e+001],
#        [ 2.00000000e+003,  7.16966776e-008, -1.18718850e-006,
#          3.75307440e-007],
#        [ 1.00000000e+002,  1.58954853e-024,  6.89576704e-050,
#          2.19316937e-276],
#        [ 1.00000000e+000,  1.04027965e+000,  1.01872620e+000,
#          8.26287566e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   315.11403676 315.11403679 315.11403675]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   44.12026147 44.12026147 44.12026147]
# distance: 3.320162447920915e+16
# +epd 0.5346678457725738   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 11138
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+02,  3.15850154e+02,  3.15850154e+02,
#          3.15850154e+02],
#        [ 4.16666660e+01,  5.03989176e+01,  5.03989175e+01,
#          5.03989175e+01],
#        [ 2.00000000e+03, -8.16047676e-07,  7.67977055e-07,
#          6.74439682e-07],
#        [ 1.00000000e+02,  6.07754772e-34,  1.66808773e-68,
#          0.00000000e+00],
#        [ 1.00000000e+00,  1.09003874e+00,  1.06047078e+00,
#          8.05501662e-01]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   315.85015425 315.85015421 315.85015422]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   50.39891755 50.39891754 50.39891755]
# distance: 3.320162387463863e+16
# +epd 0.7158088401131724   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 7406
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.78102386e+002,  3.78102386e+002,
#          3.78102386e+002],
#        [ 4.16666660e+001,  5.69732799e+001,  5.69732799e+001,
#          5.69732799e+001],
#        [ 2.00000000e+003,  6.58068934e-007, -6.69220433e-007,
#          1.64512370e-007],
#        [ 1.00000000e+002,  2.91492339e-027,  9.90419330e-056,
#          7.10366101e-300],
#        [ 1.00000000e+000,  1.20973785e+000,  1.17565348e+000,
#          8.83405286e-001]])
#  y_events: None
# ...
#          4.30762311e+001],
#        [ 2.00000000e+003,  1.25594973e-007, -8.19544196e-008,
#          4.24891730e-007],
#        [ 1.00000000e+002,  1.38204285e-015,  6.12047675e-032,
#          3.36905037e-166],
#        [ 1.00000000e+000,  1.05795062e+000,  1.01959862e+000,
#          7.04802901e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   328.66752814 328.66752815 328.66752813]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   43.07623105 43.07623105 43.07623105]
# distance: 3.3201619048197932e+16
# +epd 0.6517932963132562   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 13058
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 3.14041724e+002, 3.14041724e+002,
#         3.14041724e+002],
#        [4.16666660e+001, 4.54644596e+001, 4.54644596e+001,
#         4.54644596e+001],
#        [2.00000000e+003, 1.06030456e-006, 1.37030651e-006,
#         4.04340174e-007],
#        [1.00000000e+002, 8.31546813e-026, 2.20909469e-052,
#         1.34554303e-287],
#        [1.00000000e+000, 1.04031946e+000, 1.01708447e+000,
#         8.11446759e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   314.04172414 314.04172413 314.04172415]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   45.46445958 45.46445958 45.46445958]
# distance: 3.3201624847242172e+16
# +epd 0.6166454780913526   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 5702
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 3.50818367e+002, 3.50818367e+002,
#         3.50818367e+002],
#        [4.16666660e+001, 5.41450752e+001, 5.41450752e+001,
#         5.41450752e+001],
#        [2.00000000e+003, 4.05050818e-007, 4.35271732e-007,
#         5.25248007e-007],
#        [1.00000000e+002, 1.37007201e-027, 2.80570295e-056,
#         9.54108993e-314],
#        [1.00000000e+000, 1.11160521e+000, 1.08950599e+000,
#         8.91292224e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   350.81836667 350.81836667 350.81836667]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   54.14507522 54.14507522 54.14507522]
# distance: 3.3201609547846304e+16
# +epd 0.35298715159616645   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 6716
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  2.92314361e+002,  2.92314361e+002,
#          2.92314361e+002],
#        [ 4.16666660e+001,  4.16309593e+001,  4.16309593e+001,
#          4.16309593e+001],
#        [ 2.00000000e+003, -1.79076594e-010,  1.15413820e-006,
#          1.68584144e-006],
#        [ 1.00000000e+002,  1.33807752e-017,  5.08992891e-036,
#          4.75935458e-195],
#        [ 1.00000000e+000,  1.02145462e+000,  9.93947468e-001,
#          7.56496616e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   292.31436119 292.31436118 292.31436117]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666  41.6309593 41.6309593 41.6309593]
# distance: 3.3201633822731572e+16
# +epd 0.34505733594602417   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 13676
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  2.92562512e+002,  2.92562512e+002,
#          2.92562512e+002],
#        [ 4.16666660e+001,  4.29975628e+001,  4.29975628e+001,
#          4.29975628e+001],
#        [ 2.00000000e+003, -7.90560747e-007, -8.77372042e-007,
#          1.89102138e-007],
#        [ 1.00000000e+002,  1.97671508e-026,  1.68159341e-053,
#          6.12325568e-286],
#        [ 1.00000000e+000,  1.05910215e+000,  1.02952922e+000,
#          7.75616360e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   292.56251237 292.56251237 292.56251236]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   42.99756278 42.99756278 42.99756278]
# distance: 3.3201633655576588e+16
# +epd 0.690100628772377   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 10094
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.10490707e+002,  3.10490707e+002,
#          3.10490707e+002],
#        [ 4.16666660e+001,  4.23775184e+001,  4.23775184e+001,
#          4.23775184e+001],
#        [ 2.00000000e+003, -7.22583904e-007,  3.42839225e-007,
#          3.68599514e-007],
#        [ 1.00000000e+002,  4.66571610e-014,  5.51868824e-029,
#          1.99185358e-156],
#        [ 1.00000000e+000,  1.01971933e+000,  9.90163343e-001,
#          7.37851200e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   310.49070694 310.49070691 310.49070691]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   42.37751835 42.37751835 42.37751835]
# distance: 3.320162643439082e+16
# +epd 0.35223245365330924   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 14798
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  2.91557945e+002,  2.91557945e+002,
#          2.91557945e+002],
#        [ 4.16666660e+001,  4.76973474e+001,  4.76973474e+001,
#          4.76973474e+001],
#        [ 2.00000000e+003,  8.60912011e-007, -3.40362843e-007,
#          2.77021580e-007],
#        [ 1.00000000e+002,  1.07961941e-015,  4.11484753e-032,
#          1.24958602e-165],
#        [ 1.00000000e+000,  1.07127104e+000,  1.03055702e+000,
#          6.99517589e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   291.55794517 291.55794519 291.55794518]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   47.69734739 47.6973474  47.69734739]
# distance: 3.320163383222503e+16
# +epd 0.26436774853592454   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 2612
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.14952255e+002,  3.14952255e+002,
#          3.14952255e+002],
#        [ 4.16666660e+001,  4.69709367e+001,  4.69709367e+001,
#          4.69709367e+001],
#        [ 2.00000000e+003, -7.11503014e-007,  5.10938077e-007,
#          5.77532276e-007],
#        [ 1.00000000e+002,  7.90894328e-017,  7.77110149e-035,
#          4.74032404e-195],
#        [ 1.00000000e+000,  1.12466666e+000,  1.09965006e+000,
#          8.78135086e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   314.95225466 314.95225463 314.95225463]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   46.97093667 46.97093666 46.97093666]
# distance: 3.3201624405336724e+16
# +epd 0.29908721463000565   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 12650
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  2.93877202e+002,  2.93877202e+002,
#          2.93877202e+002],
#        [ 4.16666660e+001,  4.36415977e+001,  4.36415977e+001,
#          4.36415976e+001],
#        [ 2.00000000e+003, -5.02953810e-007, -1.88411980e-007,
#          2.19341032e-007],
#        [ 1.00000000e+002,  7.16846092e-031,  3.90842226e-062,
#          4.34777768e-322],
#        [ 1.00000000e+000,  1.06088938e+000,  1.02495766e+000,
#          7.26213206e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   293.87720183 293.87720183 293.87720182]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   43.64159765 43.64159765 43.64159765]
# distance: 3.320163309234575e+16
# +epd 0.41204911777508335   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 8696
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  2.95856516e+002,  2.95856516e+002,
#          2.95856516e+002],
#        [ 4.16666660e+001,  4.86134567e+001,  4.86134567e+001,
#          4.86134567e+001],
#        [ 2.00000000e+003, -7.65686909e-007, -1.24110422e-006,
#          1.11958274e-006],
#        [ 1.00000000e+002,  9.14283675e-027,  4.41479124e-054,
#          1.38271137e-282],
#        [ 1.00000000e+000,  1.09256566e+000,  1.05677158e+000,
#          7.57385408e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   295.85651622 295.85651623 295.8565162 ]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   48.61345675 48.61345675 48.61345674]
# distance: 3.320163204879594e+16
# +epd 0.4687897012220116   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 6548
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 3.01428797e+002, 3.01428797e+002,
#         3.01428797e+002],
#        [4.16666660e+001, 4.62535532e+001, 4.62535532e+001,
#         4.62535532e+001],
#        [2.00000000e+003, 1.47519118e-008, 2.23591559e-007,
#         7.11343159e-007],
#        [1.00000000e+002, 1.57162970e-027, 1.52094300e-055,
#         4.46315845e-288],
#        [1.00000000e+000, 1.07946647e+000, 1.04250781e+000,
#         7.35835827e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   301.42879655 301.42879655 301.42879654]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   46.25355318 46.25355318 46.25355317]
# distance: 3.320162991027956e+16
# +epd 0.3834494853129708   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 7190
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 3.36132347e+002, 3.36132347e+002,
#         3.36132347e+002],
#        [4.16666660e+001, 4.83604418e+001, 4.83604418e+001,
#         4.83604418e+001],
#        [2.00000000e+003, 1.99323319e-006, 1.73084769e-007,
#         1.65682392e-007],
#        [1.00000000e+002, 1.00087778e-023, 5.09072175e-049,
#         4.07070590e-272],
#        [1.00000000e+000, 1.26116960e+000, 1.23218261e+000,
#         9.76541959e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   336.13234705 336.13234711 336.13234711]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   48.36044179 48.36044179 48.36044179]
# distance: 3.320161577064194e+16
# +epd 0.2949087687180216   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 11876
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  2.88962227e+002,  2.88962227e+002,
#          2.88962227e+002],
#        [ 4.16666660e+001,  4.39510593e+001,  4.39510593e+001,
#          4.39510593e+001],
#        [ 2.00000000e+003, -3.82914677e-007, -4.24248114e-007,
#          1.36243186e-006],
#        [ 1.00000000e+002,  1.65310958e-020,  5.70259081e-042,
#          2.26839154e-234],
#        [ 1.00000000e+000,  1.07433819e+000,  1.05286605e+000,
#          8.60387712e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   288.96222719 288.96222719 288.96222717]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   43.95105934 43.95105934 43.95105933]
# distance: 3.3201635065201948e+16
# +epd 0.7544450242436878   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 4460
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[ 2.71666666e+002,  3.50081093e+002,  3.50081093e+002,
#          3.50081093e+002],
#        [ 4.16666660e+001,  4.92212900e+001,  4.92212900e+001,
#          4.92212900e+001],
#        [ 2.00000000e+003, -3.56623757e-007,  2.53309217e-007,
#          1.72029669e-007],
#        [ 1.00000000e+002,  3.79752421e-021,  2.45947135e-043,
#          1.92620556e-236],
#        [ 1.00000000e+000,  1.15840844e+000,  1.12879984e+000,
#          8.71303039e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   350.08109305 350.08109303 350.08109303]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   49.22129005 49.22129005 49.22129005]
# distance: 3.320161008667328e+16
# +epd 0.22888756031788143
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-107-49aa76aff130> in <module>()
#      21      if (evaluateprior(proposed_pars, model) > 0):
#      22          print('+epd', proposed_pars[0], end=' ')
# ---> 23          d = distance(proposed_pars)
#      24          if d is None:
#      25            break
#
# <ipython-input-106-de513c41254b> in distance(par)
#       4     ### stored as xdata and ydata:
#       5     par = (tuple(par),)
# ----> 6     traj = get_trajectory(timespan, initcond, t_eval, par)
#       7     print(traj)
#       8     print(c_data, traj.y[0])
#
# <ipython-input-88-f99ea88dc4a9> in get_trajectory(timespan, initcond, t_eval, pars)
#       2     #print('get_traj pars:', pars)
#       3     #print('\t+ode', end='')
# ----> 4     traj = solve_ivp(model, t_span=timespan, y0=initcond, t_eval=t_eval, args=pars)
#       5     #print('-ode', end='\t')
#       6     return traj
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     575     status = None
#     576     while status is None:
# --> 577         message = solver.step()
#     578
#     579         if solver.status == 'finished':
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/base.py in step(self)
#     180         else:
#     181             t = self.t
# --> 182             success, message = self._step_impl()
#     183
#     184             if not success:
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/rk.py in _step_impl(self)
#     144
#     145             y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
# --> 146                                    self.B, self.C, self.K)
#     147             scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     148             error_norm = self._estimate_error_norm(self.K, h, scale)
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/rk.py in rk_step(fun, t, y, f, h, A, B, C, K)
#      63     for s, (a, c) in enumerate(zip(A[1:], C[1:]), start=1):
#      64         dy = np.dot(K[:s].T, a[:s]) * h
# ---> 65         K[s] = fun(t + c * h, y + dy)
#      66
#      67     y_new = y + h * np.dot(K[:-1].T, B)
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/base.py in fun(t, y)
#     137         def fun(t, y):
#     138             self.nfev += 1
# --> 139             return self.fun_single(t, y)
#     140
#     141         self.fun = fun
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/base.py in fun_wrapped(t, y)
#      19
#      20     def fun_wrapped(t, y):
# ---> 21         return np.asarray(fun(t, y), dtype=dtype)
#      22
#      23     return fun_wrapped, y0
#
# KeyboardInterrupt:

# %%
print(d)
# Out:
# None

# %%
def get_trajectory(timespan, initcond, t_eval, pars):
    #print('get_traj pars:', pars)
    #print('\t+ode', end='')
    traj = solve_ivp(model, t_span=timespan, y0=initcond, t_eval=t_eval, args=pars)
    #print('-ode', end='\t')
    return traj

# %%
x_data = np.array([0, 2,4,24])  # input data, time points
#c_data = np.array([0, 883, 6370, 1360000])*(10**6) # input data, population/10^6
#s_data = np.array([0, 550, 1970, 91700])*(10**6) # input data, population/10^6
s_data = np.array([27166666667,1200000000.00,1766666666666.67,22666666666666.70])/1000000
c_data = np.array([41666666.67,4516666666.67,22900000000000.00,179333333333333.00])/1000000

initcond = [271.666666,41.666666,2000,100,1]

get_trajectory(timespan, initcond, x_data, (tuple(proposed_pars),))
# Out:
#   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 7052
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+02, 3.76652540e+02, 3.76652540e+02, 3.76652540e+02],
#        [4.16666660e+01, 5.33824494e+01, 5.33824494e+01, 5.33824495e+01],
#        [2.00000000e+03, 8.61087253e-07, 7.94489635e-07, 5.03019226e-07],
#        [1.00000000e+02, 1.03974317e-38, 2.13795563e-79, 0.00000000e+00],
#        [1.00000000e+00, 1.24607312e+00, 1.20263938e+00, 8.43440321e-01]])
#  y_events: None

# %%
seed()  # setting random seeds for each thread/process to avoid having the same random sequence in each thread
np.random.seed()

x_data = np.array([0, 2, 4, 24])  # input data, time points
#c_data = np.array([0, 883, 6370, 1360000])*(10**6) # input data, population/10^6
#s_data = np.array([0, 550, 1970, 91700])*(10**6) # input data, population/10^6
#s_data = np.array([271666666.67,1200000000.00,1766666666666.67,22666666666666.70])
#c_data = np.array([41666666.67,4516666666.67,22900000000000.00,179333333333333.00])

#initcond = [c_data[0],s_data[0],2000,100,1]


evaluated_distances = []
proposed_pars = sampleprior()
#selected_pars = choices(previousparlist, weights=previousweights, k=1)  # select a point from the previous sample
#proposed_pars = selected_pars + kernel.rvs()  # and perturb it

evaluateprior(proposed_pars, model)
d = distance(proposed_pars)
evaluated_distances.append(d)

# %%
distance(proposed_pars)
# Out:
#   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 8444
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0,  2,  4, 24])
#  t_events: None
#         y: array([[2.71666666e+002, 2.93553986e+002, 2.93553986e+002,
#         2.93553986e+002],
#        [4.16666660e+001, 4.81057494e+001, 4.81057494e+001,
#         4.81057494e+001],
#        [2.00000000e+003, 1.10688649e-006, 1.21248225e-007,
#         1.13697435e-006],
#        [1.00000000e+002, 1.59313437e-025, 7.20712001e-052,
#         2.67169972e-279],
#        [1.00000000e+000, 1.08648982e+000, 1.05722425e+000,
#         8.04602980e-001]])
#  y_events: None
# [4.16666667e+01 4.51666667e+03 2.29000000e+07 1.79333333e+08] [271.666666   293.55398566 293.55398567 293.55398566]
# [2.71666667e+04 1.20000000e+03 1.76666667e+06 2.26666667e+07] [41.666666   48.10574941 48.10574942 48.10574941]
# 3.3201633004920564e+16

# %%
print(d)
# Out:
# None

# %%
#for time interval (0-24h), initial conditions, timepoints for evaluation, and parameters
get_trajectory(timespan, initcond, t_eval, pars=((1,)*12,))  
print('MODEL PREDICTIONS OF SYSTEM: \n', traj)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-090c33ae3bac> in <module>()
#       1 #for time interval (0-24h), initial conditions, timepoints for evaluation, and parameters
# ----> 2 get_trajectory(timespan, initcond, t_eval, pars=((1,)*12,))
#       3 print('MODEL PREDICTIONS OF SYSTEM: \n', traj)
#
# <ipython-input-3-3a3db6a53443> in get_trajectory(timespan, initcond, t_eval, pars)
#      77     #print('get_traj pars:', pars)
#      78     #print('\t+ode', end='')
# ---> 79     traj = solve_ivp(model, t_span=timespan, y0=initcond, t_eval=t_eval, args=pars)
#      80     #print('-ode', end='\t')
#      81     return traj
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     620             # The value in t_eval equal to t will be included.
#     621             if solver.direction > 0:
# --> 622                 t_eval_i_new = np.searchsorted(t_eval, t, side='right')
#     623                 t_eval_step = t_eval[t_eval_i:t_eval_i_new]
#     624             else:
#
# <__array_function__ internals> in searchsorted(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
GeneratePar( eps_dist=10^13)
# Out:
# +epd 0.30975496777269645 -epd: 1857978367662.9756
# +epd 0.3688148271227508 -epd: 1857980577190.716
# +epd 0.6036477158975444 -epd: 1857951717209.0007
# +epd 0.3434252504097931 -epd: 1857969339238.8418
# +epd 0.2913419077628685 -epd: 1857978676597.8193
# +epd 0.7970935283946461 -epd: 1857917314976.5059
# +epd 0.43616617638570737 -epd: 1857977759708.0186
# +epd 0.7590532807498891 -epd: 1857907669847.4797
# +epd 0.45923018245094177 -epd: 1857955643379.723
# +epd 0.6199385057861203 -epd: 1857911378992.394
# +epd 0.5864611331339326 -epd: 1857937984050.0
# +epd 0.2571897026489628 -epd: 1857995507673.3462
# +epd 0.4293866907755375 -epd: 1857944787165.331
# +epd 0.3645724473245885 -epd: 1857967942683.834
# +epd 0.23121073702887243 -epd: 1857992920401.2458
# +epd 0.5478606252747205 -epd: 1857859138324.538
# +epd 0.345810051724887 -epd: 1857969482273.3267
# +epd 0.7298296161488016 -epd: 1857749910698.9197
# +epd 0.6194545952820008 -epd: 1857909222149.4062
# +epd 0.41679831472931944 -epd: 1857960409612.2651
# +epd 0.33824045149661497 -epd: 1857979450044.897
# +epd 0.4285780637425107 -epd: 1857916466656.0068
# +epd 0.6029165161872165 -epd: 1857941855712.1216
# +epd 0.5984078466296254 -epd: 1857946980268.9048
# +epd 0.6797894275346754 -epd: 1857910541742.0227
# +epd 0.27979496775419294 -epd: 1857979438581.6155
# +epd 0.3460525282292064 -epd: 1857963478499.616
# +epd 0.6105401908661051 -epd: 1857940610907.7168
# +epd 0.5544059965544417 -epd: 1857929641025.7927
# +epd 0.4837061733415054 -epd: 1857908687975.7078
# +epd 0.20917421556701526 -epd: 1857977223568.71
# +epd 0.5809540824682032 -epd: 1857904097571.006
# +epd 0.6626787503205589 -epd: 1857839521986.0564
# +epd 0.21829399347795725 -epd: 1857972241920.163
# +epd 0.6194090728419295 -epd: 1857828287114.7537
# +epd 0.4449188306769274 -epd: 1857975981980.0823
# +epd 0.7118424448505127 -epd: 1857933513006.8787
# +epd 0.3451907635578849
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-3faa1c7368a2> in <module>()
#       1 initcond = [0,0,2000,10,10]
#       2 initcond = [10^6,10^6,2000,10,10]
# ----> 3 GeneratePar( eps_dist=10^13)
#
# <ipython-input-3-944ca0a69cb8> in GeneratePar(processcall, previousparlist, previousweights, eps_dist, kernel)
#     146         if (evaluateprior(proposed_pars, model) > 0):
#     147             print('+epd', proposed_pars[0], end=' ')
# --> 148             d = distance(proposed_pars)
#     149             evaluated_distances.append(d)
#     150             print('-epd:', d)
#
# <ipython-input-3-944ca0a69cb8> in distance(par)
#      91     ### stored as xdata and ydata:
#      92     par = (tuple(par),)
# ---> 93     traj = get_trajectory(timespan, initcond, t_eval, par)
#      94     difference = np.sum(np.power(c_data - traj.y[0], 2) + np.power(s_data - traj.y[1], 2))
#      95     return difference
#
# <ipython-input-3-944ca0a69cb8> in get_trajectory(timespan, initcond, t_eval, pars)
#      77     #print('get_traj pars:', pars)
#      78     #print('\t+ode', end='')
# ---> 79     traj = solve_ivp(model, t_span=timespan, y0=initcond, t_eval=t_eval, args=pars)
#      80     #print('-ode', end='\t')
#      81     return traj
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     575     status = None
#     576     while status is None:
# --> 577         message = solver.step()
#     578
#     579         if solver.status == 'finished':
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/base.py in step(self)
#     180         else:
#     181             t = self.t
# --> 182             success, message = self._step_impl()
#     183
#     184             if not success:
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/rk.py in _step_impl(self)
#     145             y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     146                                    self.B, self.C, self.K)
# --> 147             scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     148             error_norm = self._estimate_error_norm(self.K, h, scale)
#     149
#
# KeyboardInterrupt:

# %%
GeneratePars(eps_dist=1000000000000000000000000)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-051b1b6fcc46> in <module>()
# ----> 1 GeneratePars(eps_dist=1000000000000000000000000)
#
# <ipython-input-3-944ca0a69cb8> in GeneratePars(previousparlist, previousweights, eps_dist, Npars, kernelfactor)
#     185     results = p_umap(
#     186     partial(GeneratePar, previousparlist=previousparlist,
# --> 187                 previousweights=previousweights, eps_dist=eps_dist, kernel=kernel), range(Npars))
#     188     accepted_distances = [result[1] for result in results]
#     189     evaluated_distances = [res for result in results for res in result[3]]  # flatten list
#
# /usr/local/lib/python3.7/dist-packages/p_tqdm/p_tqdm.py in p_umap(function, *iterables, **kwargs)
#      77     ordered = False
#      78     generator = _parallel(ordered, function, *iterables, **kwargs)
# ---> 79     result = list(generator)
#      80
#      81     return result
#
# /usr/local/lib/python3.7/dist-packages/p_tqdm/p_tqdm.py in _parallel(ordered, function, *iterables, **kwargs)
#      50         yield item
#      51
# ---> 52     pool.clear()
#      53
#      54
#
# /usr/local/lib/python3.7/dist-packages/pathos/multiprocessing.py in _clear(self)
#     130         if _pool and self.__nodes == _pool.__nodes:
#     131             _pool.close()
# --> 132             _pool.join()
#     133             __STATE.pop(self._id, None)
#     134         return #XXX: return _pool?
#
# /usr/local/lib/python3.7/dist-packages/multiprocess/pool.py in join(self)
#     554         elif self._state not in (CLOSE, TERMINATE):
#     555             raise ValueError("In unknown state")
# --> 556         self._worker_handler.join()
#     557         self._task_handler.join()
#     558         self._result_handler.join()
#
# /usr/lib/python3.7/threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:

# %% [markdown]
# Solving the ODEs

# %%
def pend(y, t, growthc, growths, dc, ds, KG, KA, hydrolysis, da, de, uptake, secretion):
    #let y be a vector of
    cheater,secretor,glucose,ampicillin,enzyme = y 
    #set all 5 equations
    dydt = [growthc*(glucose/(KG+glucose))*cheater - dc*ampicillin/(KA+ampicillin),
            growths*(glucose/(KG+glucose))*secretor - ds*ampicillin/(KA+ampicillin),
            - uptake*(glucose/(KG+glucose))*(cheater+secretor),
            - hydrolysis*ampicillin*enzyme - da*ampicillin,
            secretion*(glucose/(KG+glucose))*secretor - de*enzyme]
    return dydt

#set constant parameters
growthc = 0.2
growths = 0.4
dc = 0.0
ds = 0.0
KG = 1
KA = 1
hydrolysis = 1
da = 1
de = 1
uptake = 1
secretion = 1



#set initial conditions
y0 = [1, 1, 20, 1, 1]
#ODE will be solved for 0 <= x <= 10 at 101 uniform intervals 
t = np.linspace(0, 10, 101)

#solve the system of ODEs for the given time and parameters

sol = odeint(pend, y0, t, args=(growthc, growths, dc, ds, KG, KA, hydrolysis, da, de, uptake, secretion))

#plot the solutions
import matplotlib.pyplot as plt
plt.plot(t, sol[:, 0], 'b', label='cheater(t)')
plt.plot(t, sol[:, 1], 'g', label='secretor(t)')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid()
plt.show()
